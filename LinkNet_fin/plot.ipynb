# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['Naive', 'Erased']
train_means = [0.6222, 0.6178]
val_means = [0.5948, 0.6056]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, train_means, width, label='train')
rects2 = ax.bar(x + width/2, val_means, width, label='validation')

plt.ylim(0.55, 0.65)
plt.xticks(x, labels=labels)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('F1-Scores(2000 epochs)')
#ax.set_xticks(x)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
labels = ['Naive', 'Erased']
train_means = [0.6421, 0.6543]
val_means = [0.5953, 0.6215]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, train_means, width, label='train')
rects2 = ax.bar(x + width/2, val_means, width, label='validation')

plt.ylim(0.55, 0.67)
plt.xticks(x, labels)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('F1-Scores(3000 epochs)')
#ax.set_xticks(x)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
names = ["baseline", "baseline+RE", "baseline+LR_change", "baseline+RE+TTA"]
values = [0.55309, 0.57744, 0.57902, 0.59422]


plt.plot(names, values,'bo-', label="test result")
plt.ylabel("F-Score")
plt.title("Test Results")

for a, b in zip(names, values):
    plt.text(a, b, b, ha='center', va = 'bottom', fontsize = 10)

plt.show()
